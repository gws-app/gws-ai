# %%
import json

# %%
with open('nlp_dataset_faq.json','r') as file:
    training_data = json.load(file)

# %%
tag = []
for data in training_data:
    tag.append(data['context'])

# %%
print((tag))
# Out:
# ['apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'apa_itu_gangguan_mental', 'badmood', 'badmood', 'badmood', 'badmood', 'badmood', 'badmood', 'badmood', 'badmood', 'badmood', 'sapaan', 'sapaan', 'sapaan', 'sapaan', 'sapaan', 'sapaan', 'sapaan', 'sapaan', 'bunuh_diri', 'bunuh_diri', 'bunuh_diri', 'mood_emosi_senang', 'mood_emosi_sedih', 'mood_emosi_marah', 'mood_emosi_cemas', 'salam_halo', 'salam_hi_tes', 'salam_terima_kasih', 'mood_emosi_membaik', 'mood_emosi_stress_relief', 'mood_emosi_motivation', 'emosi_sedih', 'emosi_senang
# ...

# %%
tags_dict = {
    'gangguan_mental': ['apa_itu_gangguan_mental', 'penyebab_gangguan_mental', 'gejala_gangguan_mental', 
                                'cara_mengatasi_gangguan_mental', 'pengobatan_gangguan_mental', 'penanganan_gangguan_mental', 
                                'perbedaan_gangguan_mental_dan_stres', 'efek_gangguan_mental', 'penyebab_gangguan_mental', 
                                'diagnosis_gangguan_mental', 'gejala_gangguan_mental', 'pencegahan_gangguan_mental', 
                                'pengobatan_gangguan_mental', 'gangguan_mental_dan_stigma', 'gangguan_mental_untuk_anak', 
                                'gangguan_mental_dan_depresi', 'gangguan_mental_dan_kecemasan', 'gangguan_mental_dan_psikoterapi', 
                                'gangguan_mental_dan_bipolar', 'gangguan_mental_dan_psikoedukasi'],
    'badmood': ['badmood_gejala', 'badmood_penyebab', 'badmood_dampak', 'badmood_pengobatan', 'badmood_preventif', 
                'badmood_efek_jangka_panjang', 'badmood_terhadap_pekerjaan', 'badmood_solusi_pribadi', 
                'badmood_terhadap_kesehatan_fisik'],
    'sapaan': ['sapaan_pagi', 'sapaan_tanya_kabar', 'ucapan_terima_kasih', 'perkenalan_diri', 'perpisahan', 
               'kabar_baik', 'kabar_buruk', 'kabar_netral', 'agama_kepercayaan_bot'],
    'bunuh_diri': ['bunuh_diri', 'dukungan_mental_terapi', 'tanya_bantuan_terdekat','kata_mati', 'kata_mati_tidak_serius'],
    'senang': ['mood_bahagia', 'emosi_senang', 'cara_mengatasi_senang'],
    'sedih': ['mood_sedih', 'emosi_sedih', 'cara_mengatasi_sedih'],
    'marah': ['mood_marahan', 'emosi_marah', 'cara_mengatasi_marah'],
    'cemas': ['mood_cemas', 'emosi_takut', 'cara_mengatasi_cemas'],
    'membaik': ['mood_membaik', 'emosi_senang', 'cara_mengatasi_senang'],
    'stress': ['mood_stress_relief', 'emosi_sedih', 'cara_mengatasi_sedih'],
    'motivation': ['mood_motivation', 'emosi_senang', 'cara_mengatasi_senang'],
    'sedih': ['emosi_sedih', 'cara_mengatasi_sedih'],
    'senang': ['emosi_senang', 'cara_mengatasi_senang'],
    'marah': ['emosi_marah', 'cara_mengatasi_marah'],
    'takut': ['emosi_takut', 'cara_mengatasi_takut'],
    'bingung': ['emosi_bingung', 'cara_mengatasi_bingung'],
    'hampa': ['emosi_hampa', 'cara_mengatasi_hampa'],
    'takut_gagal': ['emosi_takut_gagal', 'cara_mengatasi_takut_gagal'],
    'tidak_dihargai': ['emosi_tidak_dihargai', 'cara_mengatasi_tidak_dihargai'],
    'frustrasi': ['emosi_frustrasi', 'cara_mengatasi_frustasi'],
    'kecewa': ['emosi_kecewa', 'cara_mengatasi_kecewa'],
    'lelah': ['emosi_lelah', 'cara_mengatasi_lelah'],
    'tertekan': ['emosi_tertekan', 'cara_mengatasi_tertekan'],
    'terbebani': ['emosi_terbebani', 'cara_mengatasi_terbebani'],
    'relationship': ['patah_hati', 'putus_pacar', 'bertengkar', 'baru_punya_pacar', 'jalan_dengan_pacar', 
                    'masalah_tempat_kerja', 'masalah_dengan_orang_tua', 'interaksi_positif_dengan_orang_tua', 
                    'masalah_pertemanan', 'interaksi_positif_pertemanan'],
    'self_improvement': ['stres_tugas', 'membanggakan_orangtua', 'tidak_ingin_dilahirkan', 'kehilangan_ketertarikan_hidup', 
                        'kesulitan_tidur'],
    'life_challenges': ['kehilangan_semangat','mendapat_nilai_jelek', 
                        'bot_atau_orang_asli']
}

# %%
for context in tags_dict:
    print(context)
# Out:
# gangguan_mental
# badmood
# sapaan
# bunuh_diri
# senang
# sedih
# marah
# cemas
# membaik
# stress
# motivation
# takut
# bingung
# hampa
# takut_gagal
# tidak_dihargai
# frustrasi
# kecewa
# lelah
# tertekan
# terbebani
# relationship
# self_improvement
# life_challenges

# %%
for context in tags_dict:
    for data in training_data:
        if(data['tag'] in tags_dict[context]):
            print(context+'')
            data['context'] = context
# Out:
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# gangguan_mental
# badmood
# badmood
# badmood
# badmood
# badmood
# badmood
# badmood
# badmood
# badmood
# sapaan
# sapaan
# sapaan
# sapaan
# sapaan
# sapaan
# sapaan
# sapaan
# sapaan
# bunuh_diri
# bunuh_diri
# bunuh_diri
# bunuh_diri
# bunuh_diri
# senang
# sedih
# sedih
# marah
# marah
# cemas
# cemas
# cemas
# membaik
# membaik
# stress
# stress
# stress
# motivation
# motivation
# takut
# takut
# bingung
# bingung
# hampa
# hampa
# takut_gagal
# takut_gagal
# tidak_dihargai
# tidak_dihargai
# frustrasi
# frustrasi
# kecewa
# kecewa
# lelah
# tertekan
# terbebani
# relationship
# relationship
# relationship
# relationship
# relationship
# ...

# %%
tag = []
for data in training_data:
    tag.append(data['context'])

# %%
training_data
# Out:
# [{'tag': 'apa_itu_gangguan_mental',
#   'patterns': ['Apa itu gangguan mental?',
#    'Apa maksud dari gangguan mental?',
#    'Gangguan mental itu apa sih?',
#    'Bisakah Anda jelaskan apa itu gangguan mental?',
#    'Apa arti dari gangguan mental?',
#    'Gangguan mental itu bagaimana?',
#    'Apa yang dimaksud gangguan mental?',
#    'Bisa dijelaskan tentang gangguan mental?',
#    'Apa definisi dari gangguan mental?',
#    'Gangguan mental itu sebenarnya apa?',
#    'Apa yang disebut dengan gangguan mental?',
#    'Boleh tahu apa itu gangguan mental?',
#    'Apa pengertian dari gangguan mental?',
#    'Gangguan mental itu seperti apa ya?',
#    'Apa artinya gangguan mental?',
#    'Apa saja yang masuk dalam kategori gangguan mental?',
#    'Bagaimana pengertian gangguan mental?',
#    'Apa yang termasuk dalam gangguan mental?',
#    'Gangguan mental itu maksudnya apa?',
#    'Gangguan mental itu apa ya?'],
# ...

# %%
with open('nlp_dataset_faq.json', 'w') as file:
    json.dump(training_data, file, indent=4)
